# %%
# %pip install langchain_groq langchain_core langchain_community
# Out:
# Requirement already satisfied: langchain_groq in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (0.3.8)
# Requirement already satisfied: langchain_core in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (0.3.76)
# Requirement already satisfied: langchain_community in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (0.3.29)
# Requirement already satisfied: groq<1,>=0.30.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_groq) (0.31.1)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (0.4.29)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (2.11.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain_groq) (3.10)
# Requirement already satisfied: certifi in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.4->langchain_core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.4->langchain_core) (0.4.1)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: requests<3,>=2.32.5 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (0.3.11)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.32.5->langchain_community) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langsmith>=0.3.45->langchain_core) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langsmith>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from langsmith>=0.3.45->langchain_core) (0.25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    temperature = 0,
    groq_api_key = "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",
    model_name = "llama-3.3-70b-versatile"
)
result = llm.invoke("Who is lord Ram?")
print(result.content)
# Out:
# Lord Rama is a major deity in Hinduism and is considered one of the most important figures in Hindu mythology. He is the seventh avatar (incarnation) of Lord Vishnu, the preserver of the universe, and is revered as a symbol of righteousness, duty, and morality.
#
# According to the Hindu epic, the Ramayana, Lord Rama was born as a prince in the kingdom of Ayodhya, to King Dasharatha and Queen Kausalya. He was the eldest of four brothers, including Lakshmana, Bharata, and Shatrughna.
#
# The story of Lord Rama is as follows:
#
# * He was exiled to the forest for 14 years by his stepmother, Queen Kaikeyi, who wanted her own son, Bharata, to become the king.
# * During his exile, Rama's wife, Sita, was abducted by the demon king Ravana, who took her to his kingdom in Lanka (present-day Sri Lanka).
# * Rama, along with his brother Lakshmana and the monkey god Hanuman, launched a war against Ravana to rescue Sita.
# * After a long and bloody battle, Rama defeated Ravana and rescued Sita, but not before she was forced to undergo a trial by fire to prove her purity.
# * Rama returned to Ayodhya and was crowned the king, ruling with wisdom and justice.
#
# Lord Rama is revered for his many virtues, including:
#
# * His unwavering commitment to duty (dharma) and righteousness
# * His unshakeable loyalty to his family and friends
# * His bravery and selflessness in the face of adversity
# * His compassion and forgiveness towards his enemies
#
# In Hinduism, Lord Rama is considered a role model for all individuals, and his story is seen as a guide for living a virtuous and meaningful life. His birthday, known as Rama Navami, is celebrated with great fanfare in many parts of India and other countries with significant Hindu populations.
#
# Overall, Lord Rama is a beloved and revered figure in Hinduism, and his story continues to inspire and guide people around the world.

# %%
# %pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (6.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\kaushiki\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\kaushiki\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.8.3)
# Requirement already satisfied: packaging>=19.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.0)
# Requirement already satisfied: sympy in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kaushiki\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.0)
# Requirement already satisfied: filelock in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.9.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (5.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (4.56.2)
# Requirement already satisfied: tqdm in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (0.35.0)
# Requirement already satisfied: Pillow in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->sentence_transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kaushiki\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
def initialize_llm():
  llm = ChatGroq(
    temperature = 0,
    groq_api_key = "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",
    model_name = "llama-3.3-70b-versatile"
)
  return llm

def create_vector_db():
  loader = DirectoryLoader("/content/data/", glob = '*.pdf', loader_cls = PyPDFLoader)
  documents = loader.load()
  text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)
  texts = text_splitter.split_documents(documents)
  embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
  vector_db = Chroma.from_documents(texts, embeddings, persist_directory = './chroma_db')
  vector_db.persist()

  print("ChromaDB created and data saved")

  return vector_db

def setup_qa_chain(vector_db, llm):
  retriever = vector_db.as_retriever()
  prompt_templates = """ You are a compassionate mental health chatbot. Respond thoughtfully to the following question:
    {context}
    User: {question}
    Chatbot: """
  PROMPT = PromptTemplate(template = prompt_templates, input_variables = ['context', 'question'])

  qa_chain = RetrievalQA.from_chain_type(
      llm = llm,
      chain_type = "stuff",
      retriever = retriever,
      chain_type_kwargs = {"prompt": PROMPT}
  )
  return qa_chain


def main():
  print("Intializing Chatbot.........")
  llm = initialize_llm()

  db_path = "/content/chroma_db"

  if not os.path.exists(db_path):
    vector_db  = create_vector_db()
  else:
    embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
    vector_db = Chroma(persist_directory=db_path, embedding_function=embeddings)
  qa_chain = setup_qa_chain(vector_db, llm)

  while True:
    query = input("\nHuman: ")
    if query.lower()  == "exit":
      print("Chatbot: Take Care of yourself, Goodbye!")
      break
    response = qa_chain.run(query)
    print(f"Chatbot: {response}")

if __name__ == "__main__":
  main()
# Out:
# Intializing Chatbot.........
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 68
#      65     print(f"Chatbot: {response}")
#      67 if __name__ == "__main__":
# ---> 68   main()
#
# Cell In[30], line 53, in main()
#      50 db_path = "/content/chroma_db"
#      52 if not os.path.exists(db_path):
# ---> 53   vector_db  = create_vector_db()
#      54 else:
#      55   embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
#
# Cell In[30], line 18, in create_vector_db()
#      16 def create_vector_db():
#      17   loader = DirectoryLoader("/content/data/", glob = '*.pdf', loader_cls = PyPDFLoader)
# ---> 18   documents = loader.load()
#      19   text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)
#      20   texts = text_splitter.split_documents(documents)
#
# File c:\Users\KAUSHIKI\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File c:\Users\KAUSHIKI\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_community\document_loaders\directory.py:123, in DirectoryLoader.lazy_load(self)
#     121 p = Path(self.path)
#     122 if not p.exists():
# --> 123     raise FileNotFoundError(f"Directory not found: '{self.path}'")
#     124 if not p.is_dir():
#     125     raise ValueError(f"Expected directory, got file: '{self.path}'")
#
# FileNotFoundError: Directory not found: '/content/data/'

# %%
# %pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (5.9.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.115.6)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.5.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.27.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.8.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.2->gradio) (2024.10.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.2->gradio) (14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
import gradio as gr
def initialize_llm():
  llm = ChatGroq(
    temperature = 0,
    groq_api_key = "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",
    model_name = "llama-3.3-70b-versatile"
)
  return llm

def create_vector_db():
  loader = DirectoryLoader("/content/data/", glob = '*.pdf', loader_cls = PyPDFLoader)
  documents = loader.load()
  text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)
  texts = text_splitter.split_documents(documents)
  embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
  vector_db = Chroma.from_documents(texts, embeddings, persist_directory = './chroma_db')
  vector_db.persist()

  print("ChromaDB created and data saved")

  return vector_db

def setup_qa_chain(vector_db, llm):
  retriever = vector_db.as_retriever()
  prompt_templates = """ You are a compassionate mental health chatbot. Respond thoughtfully to the following question:
    {context}
    User: {question}
    Chatbot: """
  PROMPT = PromptTemplate(template = prompt_templates, input_variables = ['context', 'question'])

  qa_chain = RetrievalQA.from_chain_type(
      llm = llm,
      chain_type = "stuff",
      retriever = retriever,
      chain_type_kwargs = {"prompt": PROMPT}
  )
  return qa_chain


print("Intializing Chatbot.........")
llm = initialize_llm()

db_path = "/content/chroma_db"

if not os.path.exists(db_path):
  vector_db  = create_vector_db()
else:
  embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
  vector_db = Chroma(persist_directory=db_path, embedding_function=embeddings)
qa_chain = setup_qa_chain(vector_db, llm)

def chatbot_response(user_input, history = []):
  if not user_input.strip():
    return "Please provide a valid input", history
  response = qa_chain.run(user_input)
  history.append((user_input, response))
  return "", history

with gr.Blocks(theme = 'Respair/Shiki@1.2.1') as app:
    gr.Markdown("# 🧠 Mental Health Chatbot 🤖")
    gr.Markdown("A compassionate chatbot designed to assist with mental well-being. Please note: For serious concerns, contact a professional.")

    chatbot = gr.ChatInterface(fn=chatbot_response, title="Mental Health Chatbot")

    gr.Markdown("This chatbot provides general support. For urgent issues, seek help from licensed professionals.")

app.launch()
# Out:
# Intializing Chatbot.........
# /usr/local/lib/python3.10/dist-packages/gradio/components/chatbot.py:248: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4826ff71d25dacf3c5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4826ff71d25dacf3c5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
